// %%
#include "../common.hpp"

// %% [markdown]
// # Preface
//
// - What is _better code_?

// %% [markdown]
// - What is _good code_?

// %% [markdown]
// - Correct
// - Efficient
// - Reusable

// %% [markdown]
// - Goals:
//     - Not prescriptive
//     - Not always achievable

// %% [markdown]
// - Not limited to C++
// - Language is a constraint
